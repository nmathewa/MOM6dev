# %%
import os
import glob
os.chdir("/home/nma/mom/general/ROMS/Input_Data/")
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Daily wind BOB
#
# ROMS
#
# daily - 1 year

# %%
wind_ROMS_12 = xr.open_dataset("Daily_ASCAT2012_BoB_wind.nc")
#wind_ROMS_13 = xr.open_dataset("Daily_ASCAT2013_BoB_wind.nc")
SLP12 = xr.open_dataset("Daily_ERAI_BoB2012PRES.nc")
flux = xr.open_dataset("Daily_INCOIS_BoB2012TROPFLUX.nc")

flux
#plt.contourf(dail_.U10.values)
# Out:
# <xarray.Dataset>
# Dimensions:  (TIME: 366, LON: 30, LAT: 30)
# Coordinates:
#   * TIME     (TIME) datetime64[ns] 2012-01-01 2012-01-02 ... 2012-12-31
#   * LON      (LON) float32 73.5 74.5 75.5 76.5 77.5 ... 99.5 100.5 101.5 102.5
#   * LAT      (LAT) float32 -0.5 0.5 1.5 2.5 3.5 4.5 ... 24.5 25.5 26.5 27.5 28.5
# Data variables:
#     T2M      (TIME, LAT, LON) float32 ...
#     Q2M      (TIME, LAT, LON) float32 ...
#     SWR      (TIME, LAT, LON) float32 ...
#     LWR      (TIME, LAT, LON) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version ?? (http://mpimet.mpg.de/cdi)
#     Conventions:  CF-1.6
#     history:      Fri Nov 20 12:34:53 2020: ncrename -v LATITUDE30_59,LAT -v ...
#     CDO:          Climate Data Operators version 1.9.3 (http://mpimet.mpg.de/...
#     NCO:          4.7.2

# %%
u = dail_.U10.values[0,0,:,:]
v = dail_.V10.values[0,0,:,:]
speed = np.sqrt((u*u) + (v*v))

#plt.contourf(speed,cmap="RdBu")
#plt.colorbar()

# %% [markdown]
# ### COAPS
#
# hourly

# %%
cfscoaps_dir = "/home/nma/mom/general/datasets/CFSv2/"
preci = xr.open_dataset(cfscoaps_dir+"cfsv2_gom-sea_2015_01hr_precip.nc")
mslp = xr.open_dataset(cfscoaps_dir + "cfsv2_gom-sec_2015_01hr_sfcprs.nc")
uv10 = xr.open_dataset(cfscoaps_dir + "cfsv2_gom-sec2_2015_01hr_uv-10m.nc")
dsfc = xr.open_dataset(cfscoaps_dir + "cfsv2_gom-sec_2015_01hr_dswsfc.nc")

dsfc
# Out:
# <xarray.Dataset>
# Dimensions:    (MT: 8760, Latitude: 123, Longitude: 172)
# Coordinates:
#     Date       (MT) float64 ...
#   * Latitude   (Latitude) float64 10.73 10.94 11.14 11.35 ... 35.26 35.47 35.67
#   * Longitude  (Longitude) float64 252.2 252.4 252.6 252.8 ... 286.8 287.0 287.2
#   * MT         (MT) datetime64[ns] 2015-01-01 ... 2015-12-31T23:00:00
# Data variables:
#     dswflx     (MT, Latitude, Longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.0
#     title:        CFSV2 0.205g 2015 01hrly sec-CERES dswsf
#     institution:  Naval Research Laboratory
#     source:       NRL .D forcing file
#     history:      Mon Jan 11 14:59:40 2021: ncatted -O -a modulo,MT,o,c,  cfs...
#     NCO:          netCDF Operators version 4.7.7 (Homepage = http://nco.sf.ne...
