# %%
import xarray as xr
import rioxarray as rio
import os

# %%
ds = xr.open_dataset("rivers_89.nc",decode_times=False).sel(
# Out:
# <xarray.Dataset>
# Dimensions:    (GRID_X_T: 2880, GRID_Y_T: 1376, TIME: 12, bnds: 2)
# Coordinates:
#   * GRID_X_T   (GRID_X_T) float32 -279.9 -279.8 -279.7 ... 79.69 79.81 79.94
#   * GRID_Y_T   (GRID_Y_T) float32 -81.94 -81.81 -81.69 ... 89.69 89.81 89.94
#   * TIME       (TIME) float64 0.46 1.46 2.46 3.46 4.46 ... 8.46 9.46 10.46 11.46
# Dimensions without coordinates: bnds
# Data variables:
#     TIME_bnds  (TIME, bnds) float64 ...
#     RIV89      (TIME, GRID_Y_T, GRID_X_T) float64 ...
# Attributes:
#     history:      PyFerret V7.43 (optimized)  1-Oct-19
#     Conventions:  CF-1.6
