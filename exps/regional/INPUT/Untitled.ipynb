# %%
import xarray as xr
import os

# %% [markdown]
# ### regional

# %%
os.chdir("/home/nma/mom/MOM6dev/exps/regional/INPUT/")

grid = xr.open_dataset("ocean_hgrid.nc")
mosaic_reg = xr.open_dataset("ocean_mosaic_india.nc")
# Out:
# <xarray.Dataset>
# Dimensions:       (ntiles: 1)
# Dimensions without coordinates: ntiles
# Data variables:
#     mosaic        |S255 ...
#     gridlocation  |S255 ...
#     gridfiles     (ntiles) |S255 ...
#     gridtiles     (ntiles) |S255 ...
# Attributes:
#     grid_version:  0.2
#     code_version:  $Name: fre-nctools-bronx-10 $
#     history:       make_solo_mosaic --num_tiles 1 --dir . --mosaic_name ocean...

# %% [markdown]
# ### Global

# %%
os.chdir("/home/nma/mom/MOM6dev/exps/global/INPUT/")
grid_glo = xr.open_dataset("ocean_hgrid.nc")
mosaic_glo = xr.open_dataset("mosaic.nc")

mosaic_glo
# Out:
# <xarray.Dataset>
# Dimensions:          (nfile_aXo: 1, nfile_aXl: 1, nfile_lXo: 1)
# Dimensions without coordinates: nfile_aXo, nfile_aXl, nfile_lXo
# Data variables: (12/14)
#     atm_mosaic_dir   |S255 ...
#     atm_mosaic_file  |S255 ...
#     atm_mosaic       |S255 ...
#     lnd_mosaic_dir   |S255 ...
#     lnd_mosaic_file  |S255 ...
#     lnd_mosaic       |S255 ...
#     ...               ...
#     ocn_mosaic       |S255 ...
#     ocn_topog_dir    |S255 ...
#     ocn_topog_file   |S255 ...
#     aXo_file         (nfile_aXo) |S255 ...
#     aXl_file         (nfile_aXl) |S255 ...
#     lXo_file         (nfile_lXo) |S255 ...
# Attributes:
#     grid_version:  0.2
#     code_version:  $Name: perth $
#     history:       /home/z1l/bin/tools/make_coupler_mosaic --atmos_mosaic atm...
