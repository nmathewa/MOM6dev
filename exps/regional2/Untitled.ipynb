# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

ds = xr.open_dataset("ocnm_0001_001_12.nc")


plt.contourf(ds.u.values[0,40,:,:])

# %%
ls
# Out:
# clean.sh    INPUT/              ocnm_0001_001_12.nc  time_stamp.out
# data_table  input.nml           ocnm_0001_002_12.nc  Untitled.ipynb
# diag_table  logfile.000000.out  ocns_0001_001_01.nc
# exitcode    MOM_input           ocns_0001_002_01.nc
# host        MOM_override        OUTPUT/
